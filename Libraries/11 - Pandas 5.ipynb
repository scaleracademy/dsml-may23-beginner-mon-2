# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Pfizer_1.csv")

# %%
data.shape
# Out:
# (18, 15)

# %%
data_melt = pd.melt(
    data,
    id_vars = ["Date", "Drug_Name", "Parameter"],
    var_name = "Time",
    value_name = "Reading"
)

# %%
# data_melt

# %%
data_tidy = data_melt.pivot(
    index = ["Date", "Time", "Drug_Name"],
    columns = "Parameter",
    values = "Reading"
)

# %%
data_tidy
# Out:
# Parameter                                    Pressure  Temperature
# Date       Time     Drug_Name
# 15-10-2020 10:30:00 diltiazem hydrochloride      18.0         20.0
#                     docetaxel injection          26.0         23.0
#                     ketamine hydrochloride        9.0         22.0
#            11:30:00 diltiazem hydrochloride      19.0         20.0
#                     docetaxel injection          29.0         25.0
# ...                                               ...          ...
# 17-10-2020 8:30:00  docetaxel injection          26.0         19.0
#                     ketamine hydrochloride       11.0         20.0
#            9:30:00  diltiazem hydrochloride       9.0         13.0
#                     docetaxel injection          27.0         20.0
#                     ketamine hydrochloride       12.0         21.0
#
# [108 rows x 2 columns]

# %%
data_tidy = data_tidy.reset_index()

# %%
data_tidy
# Out:
# Parameter        Date      Time                Drug_Name  Pressure
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0  \
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0
# ...

# %%
data_tidy.columns
# Out:
# Index(['Date', 'Time', 'Drug_Name', 'Pressure', 'Temperature'], dtype='object', name='Parameter')

# %%
data_tidy.columns.name = None

# %%
data_tidy.head()
# Out:
#          Date      Time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0  \
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20  \
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
# NaN -> Not a Number -> Value is missing

# %%
# None -> Nothing -> Value is missing

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)

# Special number within python to represent a missing value
# in a numerical column
# Out:
# float

# %%
pd.Series([1, np.nan, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
pd.Series(["1", "np.nan", "2", np.nan, None])
# Out:
# 0         1
# 1    np.nan
# 2         2
# 3       NaN
# 4      None
# dtype: object

# %%
pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
data.isna().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00
# 0  False      False      False    False    False     True    False    False  \
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
data.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
data.isna().sum(axis = 1)
# Out:
# 0     1
# 1     1
# 2     4
# 3     4
# 4     3
# 5     3
# 6     1
# 7     1
# 8     1
# 9     1
# 10    2
# 11    2
# 12    1
# 13    1
# 14    0
# 15    0
# 16    0
# 17    0
# dtype: int64

# %%
data.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0  \
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21  \
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
data.dropna(axis = 1)
# Out:
#           Date                Drug_Name    Parameter  6:30:00  10:30:00
# 0   15-10-2020  diltiazem hydrochloride  Temperature       22        20  \
# 1   15-10-2020  diltiazem hydrochloride     Pressure       14        18
# 2   15-10-2020      docetaxel injection  Temperature       18        23
# 3   15-10-2020      docetaxel injection     Pressure       23        26
# 4   15-10-2020   ketamine hydrochloride  Temperature       26        22
# 5   15-10-2020   ketamine hydrochloride     Pressure        9         9
# 6   16-10-2020  diltiazem hydrochloride  Temperature       38        40
# 7   16-10-2020  diltiazem hydrochloride     Pressure       23        24
# 8   16-10-2020      docetaxel injection  Temperature       49        56
# 9   16-10-2020      docetaxel injection     Pressure       27        28
# 10  16-10-2020   ketamine hydrochloride  Temperature       12        13
# 11  16-10-2020   ketamine hydrochloride     Pressure       15        16
# ...

# %%
data.fillna(0).head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0  \
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3  15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00
# 0      0.0     21.0     21.0       22     23.0     21.0     22.0        20  \
# 1      0.0     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      0.0     17.0       18      0.0      0.0     23.0        23
# 3     22.0      0.0     22.0       23      0.0      0.0     27.0        26
# 4      0.0     27.0      0.0       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
data["2:30:00"].mean()
# Out:
# 18.8125

# %%
data["2:30:00"].fillna(data["2:30:00"].mean())
# Out:
# 0     22.0000
# 1     13.0000
# 2     17.0000
# 3     22.0000
# 4     18.8125
# 5     18.8125
# 6     35.0000
# 7     19.0000
# 8     47.0000
# 9     24.0000
# 10     9.0000
# 11    12.0000
# 12    19.0000
# 13     4.0000
# 14    13.0000
# 15    22.0000
# 16    14.0000
# 17     9.0000
# Name: 2:30:00, dtype: float64

# %%
# data_tidy -> apply and groupby

# %%
data_tidy
# Out:
#            Date      Time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
data_tidy
# Out:
#                                    Date      Time                Drug_Name
# Drug_Name
# diltiazem hydrochloride 0    15-10-2020  10:30:00  diltiazem hydrochloride  \
#                         3    15-10-2020  11:30:00  diltiazem hydrochloride
#                         6    15-10-2020  12:30:00  diltiazem hydrochloride
#                         9    15-10-2020   1:30:00  diltiazem hydrochloride
#                         12   15-10-2020   2:30:00  diltiazem hydrochloride
# ...                                 ...       ...                      ...
# ketamine hydrochloride  95   17-10-2020   5:30:00   ketamine hydrochloride
#                         98   17-10-2020   6:30:00   ketamine hydrochloride
#                         101  17-10-2020   7:30:00   ketamine hydrochloride
#                         104  17-10-2020   8:30:00   ketamine hydrochloride
#                         107  17-10-2020   9:30:00   ketamine hydrochloride
#
# ...

# %%
def temp_mean(x):
    # x will be a group
    # in that group, we are setting the value of the entire Temp_Avg column
    # to the average value of the Temperature column
    
    x["Temp_Avg"] = x["Temperature"].mean()
    return x

# %%
data_tidy.groupby(["Drug_Name"]).apply(temp_mean)
# Out:
# Parameter                          Date      Time                Drug_Name
# Drug_Name
# diltiazem hydrochloride 0    15-10-2020  10:30:00  diltiazem hydrochloride  \
#                         3    15-10-2020  11:30:00  diltiazem hydrochloride
#                         6    15-10-2020  12:30:00  diltiazem hydrochloride
#                         9    15-10-2020   1:30:00  diltiazem hydrochloride
#                         12   15-10-2020   2:30:00  diltiazem hydrochloride
# ...                                 ...       ...                      ...
# ketamine hydrochloride  95   17-10-2020   5:30:00   ketamine hydrochloride
#                         98   17-10-2020   6:30:00   ketamine hydrochloride
#                         101  17-10-2020   7:30:00   ketamine hydrochloride
#                         104  17-10-2020   8:30:00   ketamine hydrochloride
#                         107  17-10-2020   9:30:00   ketamine hydrochloride
#
# ...

# %%
data_final = data_tidy.groupby(["Drug_Name"], group_keys = False).apply(temp_mean)

# %%
data_final
# Out:
# Parameter        Date      Time                Drug_Name  Pressure
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0  \
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature   Temp_Avg
# 0                 20.0  24.848485
# 1                 23.0  30.387097
# 2                 22.0  17.709677
# ...

# %%
data_final["Temperature"].fillna(data_final["Temp_Avg"], inplace = True)

# %%
data_final["Temperature"].isna().sum()
# Out:
# 0

# %%
# STEP 1
def pressure_mean(x):
    x["Pressure_Avg"] = x["Pressure"].mean()
    return x

# %%
# STEP 2
data_final = data_final.groupby(["Drug_Name"], group_keys = False).apply(pressure_mean)

# %%
# STEP 3
data_final["Pressure"].fillna(data_final["Pressure_Avg"], inplace = True)

# %%
data_final["Pressure"].isna().sum()
# Out:
# 0

# %%
data_final.isna().sum()
# Out:
# Parameter
# Date            0
# Time            0
# Drug_Name       0
# Pressure        0
# Temperature     0
# Temp_Avg        0
# Pressure_Avg    0
# dtype: int64

# %%
data_final
# Out:
# Parameter        Date      Time                Drug_Name  Pressure
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0  \
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature   Temp_Avg  Pressure_Avg
# 0                 20.0  24.848485     15.424242
# 1                 23.0  30.387097     25.483871
# ...

# %%
print(data_final["Temperature"].min(), data_final["Temperature"].max())
# Out:
# 8.0 58.0

# %%
# 5 - 60 -> Temperature Range

# %%
temp_points = [5, 20, 35, 50, 60]
temp_labels = ["low", "medium", "high", "very high"]

# %%
data_final["Temp_Category"] = pd.cut(
    data_final["Temperature"],
    bins = temp_points,
    labels = temp_labels
)

# %%
data_final
# Out:
# Parameter        Date      Time                Drug_Name  Pressure
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0  \
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature   Temp_Avg  Pressure_Avg Temp_Category
# 0                 20.0  24.848485     15.424242           low
# ...

# %%
data_final["Temp_Category"].value_counts()
# Out:
# Temp_Category
# low          50
# medium       38
# high         15
# very high     5
# Name: count, dtype: int64

# %%
# Data for all the drug names which contain "hydrochloride"

# %%
data_final.loc[data_final["Drug_Name"].str.contains("hydrochloride")]
# Out:
# Parameter        Date      Time                Drug_Name   Pressure
# 0          15-10-2020  10:30:00  diltiazem hydrochloride  18.000000  \
# 2          15-10-2020  10:30:00   ketamine hydrochloride   9.000000
# 3          15-10-2020  11:30:00  diltiazem hydrochloride  19.000000
# 5          15-10-2020  11:30:00   ketamine hydrochloride   9.000000
# 6          15-10-2020  12:30:00  diltiazem hydrochloride  20.000000
# ..                ...       ...                      ...        ...
# 101        17-10-2020   7:30:00   ketamine hydrochloride  12.000000
# 102        17-10-2020   8:30:00  diltiazem hydrochloride  15.424242
# 104        17-10-2020   8:30:00   ketamine hydrochloride  11.000000
# 105        17-10-2020   9:30:00  diltiazem hydrochloride   9.000000
# 107        17-10-2020   9:30:00   ketamine hydrochloride  12.000000
#
# Parameter  Temperature   Temp_Avg  Pressure_Avg Temp_Category
# 0            20.000000  24.848485     15.424242           low
# ...

# %%
# Series.str.function_name

# %%
data_final["Date"].str.split("-")
# Out:
# 0      [15, 10, 2020]
# 1      [15, 10, 2020]
# 2      [15, 10, 2020]
# 3      [15, 10, 2020]
# 4      [15, 10, 2020]
#             ...
# 103    [17, 10, 2020]
# 104    [17, 10, 2020]
# 105    [17, 10, 2020]
# 106    [17, 10, 2020]
# 107    [17, 10, 2020]
# Name: Date, Length: 108, dtype: object

# %%
data_final["Date"].str.split("-").apply(lambda x: x[2])
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 103    2020
# 104    2020
# 105    2020
# 106    2020
# 107    2020
# Name: Date, Length: 108, dtype: object

# %%
data_final["Timestamp"] = data_final["Date"] + " " + data_final["Time"]

# %%
data_final.drop(["Date", "Time"], axis = 1, inplace = True)

# %%
data_final
# Out:
# Parameter                Drug_Name  Pressure  Temperature   Temp_Avg
# 0          diltiazem hydrochloride      18.0         20.0  24.848485  \
# 1              docetaxel injection      26.0         23.0  30.387097
# 2           ketamine hydrochloride       9.0         22.0  17.709677
# 3          diltiazem hydrochloride      19.0         20.0  24.848485
# 4              docetaxel injection      29.0         25.0  30.387097
# ..                             ...       ...          ...        ...
# 103            docetaxel injection      26.0         19.0  30.387097
# 104         ketamine hydrochloride      11.0         20.0  17.709677
# 105        diltiazem hydrochloride       9.0         13.0  24.848485
# 106            docetaxel injection      27.0         20.0  30.387097
# 107         ketamine hydrochloride      12.0         21.0  17.709677
#
# Parameter  Pressure_Avg Temp_Category            Timestamp
# 0             15.424242           low  15-10-2020 10:30:00
# ...

# %%
data_final["Timestamp"] = pd.to_datetime(data_final["Timestamp"])
# Out:
# /var/folders/nn/c52y0d3j0gq59dpsswchkt2r0000gn/T/ipykernel_29780/3482943313.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data_final["Timestamp"] = pd.to_datetime(data_final["Timestamp"])

# %%
data_final
# Out:
# Parameter                Drug_Name  Pressure  Temperature   Temp_Avg
# 0          diltiazem hydrochloride      18.0         20.0  24.848485  \
# 1              docetaxel injection      26.0         23.0  30.387097
# 2           ketamine hydrochloride       9.0         22.0  17.709677
# 3          diltiazem hydrochloride      19.0         20.0  24.848485
# 4              docetaxel injection      29.0         25.0  30.387097
# ..                             ...       ...          ...        ...
# 103            docetaxel injection      26.0         19.0  30.387097
# 104         ketamine hydrochloride      11.0         20.0  17.709677
# 105        diltiazem hydrochloride       9.0         13.0  24.848485
# 106            docetaxel injection      27.0         20.0  30.387097
# 107         ketamine hydrochloride      12.0         21.0  17.709677
#
# Parameter  Pressure_Avg Temp_Category           Timestamp
# 0             15.424242           low 2020-10-15 10:30:00
# ...

# %%
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Drug_Name      108 non-null    object
#  1   Pressure       108 non-null    float64
#  2   Temperature    108 non-null    float64
#  3   Temp_Avg       108 non-null    float64
#  4   Pressure_Avg   108 non-null    float64
#  5   Temp_Category  108 non-null    category
#  6   Timestamp      108 non-null    datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(4), object(1)
# memory usage: 10.3+ KB

# %%
t = data_final["Timestamp"][0]

# %%
t
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
t.year
# Out:
# 2020

# %%
t.month
# Out:
# 10

# %%
t.day
# Out:
# 15

# %%
t.month_name()
# Out:
# 'October'

# %%
t.week
# Out:
# 42

# %%
t.date()
# Out:
# datetime.date(2020, 10, 15)

# %%
t
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
t.strftime("%D")
# Out:
# '10/15/20'

# %%
t.strftime("%d-    %m-     %y")
# Out:
# '15-    10m-     20'

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.Period.strftime.html

# %%
data_final.to_csv("Pfizer_Final.csv", sep = ",", index = False)

# %%
"A, B, C, D"
